# %% [markdown]
# ### Họ vầ tên: Tô Thanh Tiến
# ### MSSV: 17521130
# ### Lớp: CS114.K21

# %% [markdown]
# # **Phân loại chó mèo**

# %% [markdown]
# ## **Mô tả bài toán**
#
#
# 1.   Input: ảnh chó hoặc mèo
# 2.   Output: phân loại chó hay mèo
#
# <img src="https://drive.google.com/uc?export=view&id=1PmPkWCw3YI3Pf85_8GR9jVbsVeAar-OJ">

# %% [markdown]
# ## **Mô hình phân loại**
# Mô hình này mục đích là để đưa ra kết quả dự đoán xem trong hình ảnh là chó hay là mèo.
# ### **Các bước xây dựng:**
#
#
# 1.   Thu thập dữ liệu
# 2.Xử lý dữ liệu
# 3.Phân chia dữ liệu Training và Testing
# 4.Chọn model và training
# 5.Đánh giá mô hình và nhận xét
#
# ### **Thu thập dữ liệu:**
#
#
#
#
# Dữ liệu được lấy trên kaggle tên là cat and dog
# <img src="https://drive.google.com/uc?export=view&id=1Sk6utpF6YXtAcQ6g0hWDhjkdvwbLKYXQ">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# link dữ liệu:https://www.kaggle.com/tongpython/cat-and-dog
#
# #### **Số lượng hình:**
#
# **Bộ train:**
#
#
# *   4001 ảnh mèo
# *   4006 ảnh chó
#
#
#
# **Bộ test:**
#
#
# *   1012 ảnh mèo
# *   1013 ảnh chó
#
# #### **Xử lý dữ liệu**
#
# *   Chuyển ảnh màu RGB về ảnh xám
# *   Resize bức ảnh về chung một kích thước duy nhất 64x64(logistic regression), 224x224(CNN)
# *  Trích xuất đặc trưng cho bức ảnh
#
#
#
# #### **Chọn model và training**
# Dùng CNN-DL-VGG16, KNN và logistic regression
#
#
#
# #### **Dự đoán ảnh trên tập test**
# #####**CNN-DL-VGG16**
#
# <img src="https://drive.google.com/uc?export=view&id=1zw0oWwrcyacT0u3VIFZJwbtTn1xxlDK8">
# <img src="https://drive.google.com/uc?export=view&id=1_nMfisNWyzObPiKUxMax_b73w6eN8tiW">
#
# accuracy = 98%
#
# #####**Logistic Regression không dùng sklearn**
#
# <img src="https://drive.google.com/uc?export=view&id=1jHO3LyTJIZz7kS53CBpwHAme2z6_YEKC">
#
# accuracy = 55.78%
#
#
# #####**Logistic Regression với sklearn**
#
# <img src="https://drive.google.com/uc?export=view&id=1cHIbzxjNT4yo-GUPv5b_JsM_ponCSA-a">
#
# accuracy = 53.14%
#
# #####**KNN**
#
# với 0 là mèo 1 là chó
#
# ảnh chó
#
# <img src="https://drive.google.com/uc?export=view&id=1cg2FOnTmvYrmCGP8pewZkynQilY8AxZD">
#
# ảnh mèo
#
# <img src="https://drive.google.com/uc?export=view&id=1jXesUcTv6RfHl3VR1JexB6Zi1NG4QopS">
#
# accuracy = 44.74%

# %% [markdown]
# ## **Đánh giá mô hình**
# ### **Nhận xét**
#
#
#
# *   Mô hình CNN ra kết quả tốt nhất lên tới 98% và mô hình KNN là kết quả thấp nhất
# *   Mô hình CNN ra kết quả cao nhất vì mô hình CNN là một mô hình cao cấp hơn ,so với CNN các mô hình khác có thể coi là khá đơn giản , CNN rút trích đặc trưng và đánh giá tốt hơn.
